# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufosbinu/30-Day-AI-UX-Sprint/blob/main/Day5_Conditional_Expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("Enter the first number:"))
num2=int(input("Enter the second number"))
if num1>num2:
   print("num1 is larger",num1)
else:
   print("num2 is larger",num2)
# Out:
# Enter the first number:20
# Enter the second number10
# num1 is larger 20

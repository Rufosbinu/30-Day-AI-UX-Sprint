# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufosbinu/30-Day-AI-UX-Sprint/blob/main/Day6_For_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers=[14,87,23,98,34,90,45,12]
for i in range(1):
    print(numbers)
    i=i+1
# Out:
# [14, 87, 23, 98, 34, 90, 45, 12]

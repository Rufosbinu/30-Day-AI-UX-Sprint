# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufosbinu/30-Day-AI-UX-Sprint/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Create a dictionary holding data for your sprint
sprint_data = {
    "day": 2,
    "topic": "Python Basics",
    "status": "In Progress"
}

# 2. Modify the data programmatically
sprint_data["status"] = "Completed!"

# 3. Print the result to the screen
print(f"Day {sprint_data['day']} task is officially {sprint_data['status']}")
# Out:
# Day 2 task is officially Completed!

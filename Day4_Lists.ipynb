# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufosbinu/30-Day-AI-UX-Sprint/blob/main/Day4_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers=[10,20,30,40,50,60]
print(numbers)
print(numbers[4])
# Out:
# [10, 20, 30, 40, 50, 60]
# 50

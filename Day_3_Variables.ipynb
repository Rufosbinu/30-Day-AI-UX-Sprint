# %% [markdown]
# <a href="https://colab.research.google.com/github/Rufosbinu/30-Day-AI-UX-Sprint/blob/main/Day_3_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name='abcd'
phone_no=1234567890
student= True
print(name)
print(phone_no)
print(student)
# Out:
# abcd
# 1234567890
# True
